# %%
import pandas as pd

# %%
dataset = pd.read_csv('/Users/kaholi3/Documents/Xccelerate/Tesla.csv')
dataset.head()
# Out:
#    Unnamed: 0  Year  Tesla_Sales         IXIC         CL  Household Income  \
# 0           0  2009      111.943  1845.384962  62.094088             63573
# 1           1  2010      116.744  2349.893531  79.609881             62323
# 2           2  2011      204.242  2677.440750  95.114405             60969
# 3           3  2012      413.256  2965.558847  94.213520             60732
# 4           4  2013     2013.496  3541.292188  98.046825             60869
#
#    Family Income  Capita Income  Vehicle_Sales
# 0          77322          33430       10347715
# 1          75477          32452       11510416
# 2          74192          32243       12695712
# 3          73920          32297       15376264
# 4          74593          32833       15490245

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              13 non-null     int64
#  1   Tesla_Sales       13 non-null     float64
#  2   IXIC              13 non-null     float64
#  3   CL                13 non-null     float64
#  4   Household Income  13 non-null     int64
#  5   Family Income     13 non-null     int64
#  6   Capita Income     13 non-null     int64
#  7   Vehicle_Sales     13 non-null     int64
# dtypes: float64(3), int64(5)
# memory usage: 960.0 bytes

# %%
X = dataset.iloc[:, [0,2,3,4,5,6,7]].values
y = dataset.iloc[:, 1].values

# %%
X
# Out:
# array([[2.00900000e+03, 1.84538496e+03, 6.20940875e+01, 6.35730000e+04,
#         7.73220000e+04, 3.34300000e+04, 1.03477150e+07],
#        [2.01000000e+03, 2.34989353e+03, 7.96098810e+01, 6.23230000e+04,
#         7.54770000e+04, 3.24520000e+04, 1.15104160e+07],
#        [2.01100000e+03, 2.67744075e+03, 9.51144047e+01, 6.09690000e+04,
#         7.41920000e+04, 3.22430000e+04, 1.26957120e+07],
#        [2.01200000e+03, 2.96555885e+03, 9.42135200e+01, 6.07320000e+04,
#         7.39200000e+04, 3.22970000e+04, 1.53762640e+07],
#        [2.01300000e+03, 3.54129219e+03, 9.80468253e+01, 6.08690000e+04,
#         7.45930000e+04, 3.28330000e+04, 1.54902450e+07],
#        [2.01400000e+03, 4.37510355e+03, 9.29067856e+01, 6.14680000e+04,
#         7.55050000e+04, 3.30940000e+04, 1.64240170e+07],
#        [2.01500000e+03, 4.94555354e+03, 4.87613492e+01, 6.37840000e+04,
#         7.80610000e+04, 3.42840000e+04, 1.74049700e+07],
# ...

# %%
y
# Out:
# array([  111.943,   116.744,   204.242,   413.256,  2013.496,  3198.356,
#         4046.025,  7000.132, 11759.   , 21461.   , 24578.   , 31536.   ,
#        53823.   ])

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, color = 'blue', label='test')   
plt.plot(y_pred, color='red', label='pred')
plt.show()

# %%
#Building optimal model using Backward Elimination
import statsmodels.api as sm
X = np.append(arr = np.ones((13, 1)).astype(int), values = X, axis = 1)

#Step 2 of backward elimination
X_opt = np.array(X[:, [0,1,2,3,4,5,6,7]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     199.1
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           8.25e-06
# Time:                        16:46:43   Log-Likelihood:                -107.41
# No. Observations:                  13   AIC:                             230.8
# Df Residuals:                       5   BIC:                             235.3
# Df Model:                           7
# ...

# %%
X_opt = np.array(X[:, [0,1,2,3,4,5,6]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     221.8
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           8.98e-07
# Time:                        16:46:43   Log-Likelihood:                -108.89
# No. Observations:                  13   AIC:                             231.8
# Df Residuals:                       6   BIC:                             235.7
# Df Model:                           6
# ...

# %%
X_opt = np.array(X[:, [0,1,2,3,4,6]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     280.7
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           6.65e-08
# Time:                        16:46:44   Log-Likelihood:                -109.55
# No. Observations:                  13   AIC:                             231.1
# Df Residuals:                       7   BIC:                             234.5
# Df Model:                           5
# ...

# %%
X_opt = np.array(X[:, [0,1,2,3,5]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     414.1
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           2.66e-09
# Time:                        16:46:44   Log-Likelihood:                -109.34
# No. Observations:                  13   AIC:                             228.7
# Df Residuals:                       8   BIC:                             231.5
# Df Model:                           4
# ...

# %%
X_opt = np.array(X[:, [0,1,2,3]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     157.5
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           4.28e-08
# Time:                        16:46:44   Log-Likelihood:                -118.16
# No. Observations:                  13   AIC:                             244.3
# Df Residuals:                       9   BIC:                             246.6
# Df Model:                           3
# ...

# %%
X_opt = np.array(X[:, [0,2,3]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     167.2
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           2.07e-08
# Time:                        16:46:44   Log-Likelihood:                -121.03
# No. Observations:                  13   AIC:                             248.1
# Df Residuals:                      10   BIC:                             249.8
# Df Model:                           2
# ...

# %%
X_opt = np.array(X[:, [0,2]], dtype=float)
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# /Users/kaholi3/opt/anaconda3/envs/xccelerate/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     347.4
# Date:                Tue, 15 Nov 2022   Prob (F-statistic):           1.14e-09
# Time:                        16:46:45   Log-Likelihood:                -121.39
# No. Observations:                  13   AIC:                             246.8
# Df Residuals:                      11   BIC:                             247.9
# Df Model:                           1
# ...

# %%
### as x1 is the most relevant data, which is IXIC, will perform prediction with it

# %%
dataset2 = dataset.filter(['IXIC','Tesla_Sales'])

# %%
dataset2
# Out:
#             IXIC  Tesla_Sales
# 0    1845.384962      111.943
# 1    2349.893531      116.744
# 2    2677.440750      204.242
# 3    2965.558847      413.256
# 4    3541.292188     2013.496
# 5    4375.103553     3198.356
# 6    4945.553540     4046.025
# 7    4987.792947     7000.132
# 8    6235.298914    11759.000
# 9    7425.957811    21461.000
# 10   7940.129365    24578.000
# 11  10201.506435    31536.000
# 12  14371.662404    53823.000

# %%
import numpy as nm  

x_BE= dataset2.iloc[:, :-1].values  
y_BE= dataset2.iloc[:, 1].values  
  
  
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_BE_train, x_BE_test, y_BE_train, y_BE_test= train_test_split(x_BE, y_BE, test_size= 0.2, random_state=0)  
  
#Fitting the MLR model to the training set:  
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(nm.array(x_BE_train).reshape(-1,1), y_BE_train)  
  
#Predicting the Test set result;  
y_BE_pred= regressor.predict(x_BE_test)  
  
#Cheking the score  
print('Train Score: ', regressor.score(x_BE_train, y_BE_train))  
print('Test Score: ', regressor.score(x_BE_test, y_BE_test))
# Out:
# Train Score:  0.9746987591739349
# Test Score:  0.9319888845312421

# %%
plt.plot(y_BE_test, color = 'blue', label='test')   
plt.plot(y_BE_pred, color='red', label='pred')
plt.show()

# %%
### to compare the difference between 2 approaches

# %%
pred_df = pd.DataFrame({'Actual Value':y_test,'Predicted Value':y_pred,'Difference':y_test-y_pred})

# %%
pred_df
# Out:
#    Actual Value  Predicted Value   Difference
# 0      4046.025      5831.845032 -1785.820032
# 1     31536.000     36638.177729 -5102.177729
# 2      2013.496      3126.598056 -1113.102056

# %%
pred_df2 = pd.DataFrame({'Actual Value':y_BE_test,'Predicted Value':y_BE_pred,'Difference':y_BE_test-y_BE_pred})

# %%
pred_df2
# Out:
#    Actual Value  Predicted Value   Difference
# 0      4046.025      9696.465801 -5650.440801
# 1     31536.000     33317.850921 -1781.850921
# 2      2013.496      3385.412623 -1371.916623
